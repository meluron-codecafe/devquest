# %%
#hide

# %%
#hide
import utils
utils.hero("Using librosa's tempo detector")
# Out:
#     <div style="
#         position: relative;
#         display: flex;
#         align-items: center;
#         justify-content: flex-start;
#         min-height: 80px;
#         width: 800px;
#         background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
#         padding: 20px;
#         border-radius: 12px;
#         box-shadow: 0 4px 15px rgba(0, 0, 0, 0.1);
#         border: 1px solid #e1e8ed;
#         margin: 10px 0;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     ">
#
#         <!-- GitHub Icon + Name in top-right -->
#         <a href="https://github.com/meluron-codecafe" target="_blank" style="
#             position: absolute;
#             top: 16px;
#             right: 20px;
#             display: flex;
#             align-items: center;
#             text-decoration: none;
#             color: #333;
#             font-size: 14px;
#             font-weight: 500;
#             gap: 6px;
#         ">
#             <img src="https://cdn-icons-png.flaticon.com/512/25/25231.png"
#                  alt="GitHub"
#                  style="width: 18px; height: 18px; display: inline-block; vertical-align: middle;">
#             <span style="transform: translateY(-1px); line-height: 1;">
#                 /meluron-codecafe
#             </span>
#         </a>
#
#         <!-- Logo + Label stacked vertically -->
#         <div style="
#             display: flex;
#             flex-direction: column;
#             align-items: center;
#             justify-content: center;
#             margin-right: 35px;
#         ">
#             <a href="https://meluron-codecafe.github.io/DevQuest/">
#                 <img src="https://raw.githubusercontent.com/meluron/assets/refs/heads/main/logos/meluron-codecafe/DevQuest/icon_with_text.png"
#                      alt="My Logo"
#                      style="
#                         width: 120px;
#                         height: 50px;
#                         border-radius: 5px;
#                         box-shadow: 0 3px 10px rgba(253, 138, 9, 0.3);
#                      ">
#             </a>
#             <div style="
#                 font-size: 13px;
#                 color: #fd8a09;
#                 font-weight: bold;
#                 margin-top: 6px;
#                 text-align: center;
#             ">
#             </div>
#         </div>
#
#         <!-- Question Badge -->
#         <div style="
#             font-size: 14px;
#             background: linear-gradient(135deg, #667eea, #764ba2);
#             color: white;
#             padding: 8px 10px;
#             border-radius: 5px;
#             display: inline-flex;
#             align-items: center;
#             gap: 6px;
#             font-weight: 600;
#             box-shadow: 0 3px 12px rgba(102, 126, 234, 0.3);
#             margin-top: -10px;
#         ">
#             Using librosa's tempo detector
#
#         </div>
#     </div>

# %% [markdown]
# Usign `librosa` tempo detector is straight forward.

# %%
import librosa

# %%
tempo_comparison_report_df = pd.read_csv("../../../meluron-toolbox/musa/data/reports/20250623-151215_bpm_report.csv")
tempo_comparison_report_summary = pd.read_csv("../../../meluron-toolbox/musa/data/reports/20250623-151215_bpm_summary.csv")

# %%
tempo_comparison_report_df
# Out:
#                                              SongName  LabelledTempo  \
# 0              Dhanda Nyoliwala - Russian Bandana.mp3             83
# 1          Badshah, Karan Aujla, Hiten - God Damn.mp3             95
# 2   Atif Aslam, Shreya Ghoshal, Sachin-Jigar - Piy...             84
# 3   Vishal Mishra, Rashmeet Kaur - Janiye (from th...             76
# 4     Jasleen Royal, Ujjwal Kashyap - Sang Rahiyo.mp3             95
# 5           Bayaan, Hasan Raheem, Rovalio - Maand.mp3            140
# 6   Atif Aslam, Alisha Chinai, Pritam - Tera Hone ...            120
# 7    Cheema Y, Gur Sidhu, Jasmeen Akhtar - Police.mp3             90
# 8   Faheem Abdullah, Rauhan Malik, Amir Ameer - Is...             95
# 9                  Diljit Dosanjh - Born to Shine.mp3             90
# 10   Guru Randhawa, Sanjoy, Gill Machhrai - Qatal.mp3             96
# 11       Atif Aslam, Hadiqa Kiani - Hona Tha Pyar.mp3            103
# 12  Vishal-Shekhar, KK, Shilpa Rao, Anvita Dutt Gu...             80
# 13      Atif Aslam, Jyotica Tangri - O Meri Laila.mp3            108
# 14          Atif Aslam, Shiraz Uppal - Pehli Dafa.mp3            113
# 15   AP Dhillon, Gurinder Gill, Intense - Excuses.mp3             95
# 16  Himesh Reshammiya, Ankit Tiwari, Palak Muchhal...             75
# 17  Atif Aslam, Roop Kumar Rathod, Mithoon, Naresh...             90
# 18  Himesh Reshammiya, Arijit Singh, Shabbir Ahmed...            120
# 19                               Arko - Nazm Nazm.mp3             82
# 20  Kailash Kher, Paresh Kamath, Naresh Kamath - T...             53
# 21  Atif Aslam, Manoj Muntashir - Tere Sang Yaara.mp3             76
# 22       Diljit Dosanjh, thiarajxtt - Kinni Kinni.mp3             97
# 23  Vishal-Shekhar, Shafqat Amanat Ali, Sunidhi Ch...            140
# 24              Josh Brar - Tere Bina Na Guzara E.mp3             75
#
#     ComputedTempo (Musa)  ComputedTempo (Librosa)  TempoError (Musa)  \
# 0                    166                       83                0.0
# 1                    187                       93                1.5
# 2                    166                      166                1.0
# 3                    149                      151                1.5
# 4                    187                       93                1.5
# 5                    139                      139                1.0
# 6                    120                      120                0.0
# 7                    181                       90                0.5
# 8                    193                       95                1.5
# 9                    181                       90                0.5
# 10                   142                      126               25.0
# 11                   103                      103                0.0
# 12                   157                       79                1.5
# 13                   107                      107                1.0
# 14                   113                      112                0.0
# 15                   193                       95                1.5
# 16                   149                       99                0.5
# 17                   181                       90                0.5
# 18                   120                      117                0.0
# 19                   162                      166                1.0
# 20                   162                      161               12.5
# 21                   149                      101                1.5
# 22                   146                      191               24.0
# 23                   139                      139                1.0
# 24                   149                       74                0.5
#
#     TempoError (Librosa)
# 0                   0.00
# 1                   2.00
# 2                   1.00
# 3                   0.50
# 4                   2.00
# 5                   1.00
# 6                   0.00
# 7                   0.00
# 8                   0.00
# 9                   0.00
# 10                 30.00
# 11                  0.00
# 12                  1.00
# 13                  1.00
# 14                  1.00
# 15                  0.00
# 16                 24.00
# 17                  0.00
# 18                  3.00
# 19                  1.00
# 20                 12.75
# 21                 25.00
# 22                  1.50
# 23                  1.00
# 24                  1.00

# %%
tempo_comparison_report_summary
# Out:
#    TotalTempoError (Musa)  TotalTempoError (Librosa)  AvgTempoError (Musa)  \
# 0                    79.5                     108.75                  3.18
#
#    AvgTempoError (Librosa)
# 0                     4.35

# %% [markdown]
# After this analysis, I felt the need to monitor `librosa` tempo detection closely. Let us do an experiment.

# %%
# Importing stuff, as usual
import librosa
import numpy as np
import IPython.display as ipd

from musa.music import MusicLoader
from musa.tempo import TempoDetector
from musa.plot import Plotter

music_loader = MusicLoader()
tempo_detector = TempoDetector()
plotter = Plotter()

# %%
SR = 44100

def generate_metronome(bpm: int, duration_min: int):

    beat_dur_sec = (60 / bpm) # Seconds
    duration_sec = duration_min * 60 # Seconds
    beat_pos_sec = np.arange(0, duration_sec, beat_dur_sec)
    metronome = librosa.clicks(times=beat_pos_sec, sr=SR, click_freq=1000, click_duration=0.05)

    return metronome

metronomes = [] # List storing metronomes at different BPMs

for bpm in range(80, 300, 10):
    metro = generate_metronome(bpm=bpm, duration_min=1)
    music = music_loader.load_from_signal(x=metro, sr=SR, name=f"metro-{bpm}")
    metronomes.append(music)

# %%
tempos_musa = []
tempos_librosa = []

for metronome in metronomes:
    tempo_musa = tempo_detector.detect_tempo(music=metronome)
    tempo_librosa = tempo_detector.detect_tempo_with_librosa(music=metronome)
    
    tempos_musa.append(tempo_musa.bpm)
    tempos_librosa.append(tempo_librosa.bpm)

    print(f"========= {metronome.name} ==============")
    print(f"Librosa: {tempo_librosa.bpm}  |  Custom: {tempo_musa.bpm}\n\n")
# Out:
# ========= metro-80 ==============
# Librosa: 79  |  Custom: 80
#
#
# ========= metro-90 ==============
# Librosa: 90  |  Custom: 89
#
#
# ========= metro-100 ==============
# Librosa: 99  |  Custom: 99
#
#
# ========= metro-110 ==============
# Librosa: 109  |  Custom: 111
#
#
# ========= metro-120 ==============
# Librosa: 120  |  Custom: 120
#
#
# ========= metro-130 ==============
# Librosa: 129  |  Custom: 130
#
#
# ========= metro-140 ==============
# Librosa: 139  |  Custom: 139
#
#
# ========= metro-150 ==============
# Librosa: 74  |  Custom: 150
#
#
# ========= metro-160 ==============
# Librosa: 161  |  Custom: 162
#
#
# ========= metro-170 ==============
# Librosa: 84  |  Custom: 171
#
#
# ========= metro-180 ==============
# Librosa: 178  |  Custom: 181
#
#
# ========= metro-190 ==============
# Librosa: 191  |  Custom: 187
#
#
# ========= metro-200 ==============
# Librosa: 99  |  Custom: 200
#
#
# ========= metro-210 ==============
# Librosa: 105  |  Custom: 127
#
#
# ========= metro-220 ==============
# Librosa: 109  |  Custom: 107
#
#
# ========= metro-230 ==============
# Librosa: 114  |  Custom: 107
#
#
# ========= metro-240 ==============
# Librosa: 120  |  Custom: 127
#
#
# ========= metro-250 ==============
# Librosa: 126  |  Custom: 166
#
#
# ========= metro-260 ==============
# Librosa: 129  |  Custom: 153
#
#
# ========= metro-270 ==============
# Librosa: 135  |  Custom: 193
#
#
# ========= metro-280 ==============
# Librosa: 139  |  Custom: 127
#
#
# ========= metro-290 ==============
# Librosa: 143  |  Custom: 187
