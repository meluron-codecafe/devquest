# %%
from musa.signals.signal1d import Signal1D

# %%
import numpy as np

# %%
signal = Signal1D(y=np.sin(np.arange(0, 5, 0.001) * 2*np.pi*10))

# %%
signal
# Out:
# Signal1D(
#   Name: 'Signal-1D',
#   Inheritance: Signal1D → Signal
#   Plugin Chain: (none)
# )

# %%
signal.trim(region=(1, 100)).plot()
# Out:
# Signal1D(
#   Name: 'Signal-1D Trimmed (1–100)',
#   Inheritance: Signal1D → Signal
#   Plugin Chain: trim(region=(1, 100))
# )
