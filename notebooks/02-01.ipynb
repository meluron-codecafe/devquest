# %%
#hide

# %%
#hide
import utils
utils.hero("What do we mean by the tempo/pace of a song?")
# Out:
#     <div style="
#         position: relative;
#         display: flex;
#         align-items: center;
#         justify-content: flex-start;
#         min-height: 80px;
#         width: 800px;
#         background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
#         padding: 20px;
#         border-radius: 12px;
#         box-shadow: 0 4px 15px rgba(0, 0, 0, 0.1);
#         border: 1px solid #e1e8ed;
#         margin: 10px 0;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     ">
#
#         <!-- GitHub Icon + Name in top-right -->
#         <a href="https://github.com/meluron-codecafe" target="_blank" style="
#             position: absolute;
#             top: 16px;
#             right: 20px;
#             display: flex;
#             align-items: center;
#             text-decoration: none;
#             color: #333;
#             font-size: 14px;
#             font-weight: 500;
#             gap: 6px;
#         ">
# ...

# %%
import pandas as pd

# %%
pd.read_csv("../../../meluron-toolbox/musa/data/reports/20250619-173024_bpm_report.csv")
# Out:
#                                              SongName  LabelledTempo  \
# 0              Dhanda Nyoliwala - Russian Bandana.mp3             83
# 1          Badshah, Karan Aujla, Hiten - God Damn.mp3             95
# 2   Atif Aslam, Shreya Ghoshal, Sachin-Jigar - Piy...             84
# 3   Vishal Mishra, Rashmeet Kaur - Janiye (from th...             76
# 4     Jasleen Royal, Ujjwal Kashyap - Sang Rahiyo.mp3             95
# 5           Bayaan, Hasan Raheem, Rovalio - Maand.mp3            140
# 6   Atif Aslam, Alisha Chinai, Pritam - Tera Hone ...              1
# 7    Cheema Y, Gur Sidhu, Jasmeen Akhtar - Police.mp3             90
# 8   Faheem Abdullah, Rauhan Malik, Amir Ameer - Is...             95
# 9                  Diljit Dosanjh - Born to Shine.mp3             90
# 10   Guru Randhawa, Sanjoy, Gill Machhrai - Qatal.mp3             96
# 11       Atif Aslam, Hadiqa Kiani - Hona Tha Pyar.mp3            103
# 12  Vishal-Shekhar, KK, Shilpa Rao, Anvita Dutt Gu...             80
# ...
