# %% [markdown]
# <div style="font-family: 'Georgia', serif; border-left: 3px solid #ccc; padding-left: 12px; margin-bottom: 1em;">
# <h2 style="margin: 0; color: #EF8C00; font-size: 2.4em; padding-left: 0; text-indent: 0;">
#     Z Transform
# </h2>
# <p style="margin: 6px 0 0; color: #777; font-size: 1em;">
#
# </p>
# </div>

# %%
import numpy as np
import modusa as ms

# %%
sr = 44100
x = np.random.randn(3*sr)
h = np.array([1, 1])
y = np.convolve(x, h)

# %%
ms.plot1d((x, ))
ms.plot1d((y, ))

# %%
y
# Out:
# array([ 0.22307452, -0.37526889, -0.43328044, ...,  0.80925864,
#         0.47884142,  0.04892763], shape=(132301,))

# %%
x
# Out:
# array([ 0.22307452, -0.59834341,  0.16506297, ...,  0.37934484,
#         0.42991379,  0.04892763], shape=(132300,))
